# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# #Importações realizadas

# %%
df = pd.read_excel('dados.rev2.xlsx')
df.head(11)
# Out:
#          Data                   Categoria        Tipo   Razão Social   Valor  \
# 0  2024-01-05                    Serviços  Fornecedor      PowerCont  1500.0
# 1  2024-01-06  Serviços - Desenvolvimento     Cliente        BuildIt  8000.0
# 2  2024-01-07  Serviços - Desenvolvimento     Cliente  TechSolutions  2500.0
# 3  2024-01-08      Serviços -Consultoria      Cliente    GreenEnergy  6000.0
# 4  2024-01-09  Serviços - Desenvolvimento     Cliente     Innovatech  8000.0
# 5  2024-01-10                    Serviços  Fornecedor      ServiPlus   800.0
# 6  2024-01-11  Serviços - Desenvolvimento     Cliente     Innovatech  6500.0
# 7  2024-01-12      Serviços -Consultoria      Cliente    GreenEnergy  1200.0
# 8  2024-01-15                Fornecimento  Fornecedor    SupplyHouse  3000.0
# 9  2024-01-17      Serviços -Consultoria      Cliente       SunPower  9500.0
# 10 2024-01-18  Serviços - Desenvolvimento     Cliente     Innovatech   950.0
#
#       Transação
# 0     Pagamento
# 1   Recebimento
# 2   Recebimento
# 3   Recebimento
# 4   Recebimento
# 5     Pagamento
# 6   Recebimento
# 7   Recebimento
# 8     Pagamento
# 9   Recebimento
# 10  Recebimento
